# %% [markdown]
# ## gold star

# %%
input = ["11-22", "95-115", "998-1012", "1188511880-1188511890", "222220-222224", "1698522-1698528", 
"446443-446449", "38593856-38593862", "565653-565659", "824824821-824824827", "2121212118-2121212124"]

count = []
for item in input:
    input_split = item.split("-")
    start = int(input_split[0])
    stop = int(input_split[1])
    for i in range(start, stop+1):
        i_string = str(i)
        halfway_first = int(len(i_string)/2)
        halfway_second = int(len(i_string)/2)
        first_half = i_string[0:halfway_first]
        second_half = i_string[halfway_second:]
        if first_half == second_half:
            count.append(i)
        #elif i_string.startswith("0"):
            #count.append(i)

add_ids = 0
for item in count:
    add_ids += item

print(add_ids)
# Out:
# 1227775554

# %%
input_orig = "12077-25471,4343258-4520548,53-81,43661-93348,6077-11830,2121124544-2121279534,631383-666113,5204516-5270916,411268-591930,783-1147,7575717634-7575795422,8613757494-8613800013,4-19,573518173-573624458,134794-312366,18345305-18402485,109442-132958,59361146-59451093,1171-2793,736409-927243,27424-41933,93-216,22119318-22282041,2854-4778,318142-398442,9477235089-9477417488,679497-734823,28-49,968753-1053291,267179606-267355722,326-780,1533294120-1533349219"

input = input_orig.split(",")

count = []
for item in input:
    input_split = item.split("-")
    start = int(input_split[0])
    stop = int(input_split[1])
    for i in range(start, stop+1):
        i_string = str(i)
        halfway_first = int(len(i_string)/2)
        halfway_second = int(len(i_string)/2)
        first_half = i_string[0:halfway_first]
        second_half = i_string[halfway_second:]
        if first_half == second_half:
            count.append(i)
        #elif i_string.startswith("0"):
            #count.append(i)

add_ids = 0
for item in count:
    add_ids += item

print(add_ids)
# Out:
# 40214376723

# %% [markdown]
# ## silver star
