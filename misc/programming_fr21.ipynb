# %% [markdown]
# # Friday (21.11.)

# %% [markdown]
# ### Rosalind Mendel's First Law (IPRB)

# %%
#k/N * (k-1/N-1) * 1 + k/N * (m/N-1) * 1 + k/N * (n/N-1) * 1 + 
#m/N * (k/N-1) * 1 + m/N * (m-1/N-1) * 3/4 + m/N * (n/N-1) * 1/2 + 
#n/N * (k/N-1) * 1 + n/N * (m/N-1) * 1/2

# %%
k = 23
m = 27
n = 26
N = k + m + n

P1 = k/N
P2 = ((m/N) * (k/(N-1))) + ((m/N)*((m-1)/(N-1))*(3/4)) + ((m/N)*(n/(N-1))*(1/2))
P3 = ((n/N)*(k/(N-1))) + ((n/N)*(m/(N-1) * 1/2))


pA = P1 + P2 + P3
print(pA)
# Out:
# 0.7320175438596491

# %%
k = 2
m = 2
n = 2
N = k + m + n

x = (k/N) + ((m/(N*(N-1))) * ((4*k + 3*m + 2*n - 3)/4)) + ((n/(N*(N-1)) * ((2*k + m)/2)))

print(x)
# Out:
# 0.7833333333333332
