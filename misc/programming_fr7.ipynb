# %% [markdown]
# # Friday (07.11.)

# %%
s = "The quick brown fox jumps over the lazy dog"

# %%
s.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
s[10]
# Out:
# 'b'

# %% [markdown]
# ### lists of things
# * things in list in specific order
# * mutable - can be changed after creation
# * can contain numbers, strings and anything else
#
#
# * true - false (Bouelian operators)
# * running method on string always returns string (immutable)
# * string = collections: set of characters where order matters --> similar to list

# %%
shopping = ["bread", "potatoes", "eggs", "flour", "rubber duck", "pizza", "milk"]

# %%
shopping
# Out:
# ['bread', 'potatoes', 'eggs', 'flour', 'rubber duck', 'pizza', 'milk']

# %%
shopping.sort() #alphabetically

# %%
shopping
# Out:
# ['bread', 'eggs', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
shopping.append("cheese") #add at end of list

# %%
shopping
# Out:
# ['bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck',
#  'cheese']

# %%
shopping.insert(0, "cheese") #insert at defined position in list

# %%
shopping
# Out:
# ['cheese',
#  'bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck',
#  'cheese']

# %%
shopping.pop() #removes last position from list
# Out:
# 'cheese'

# %%
shopping
# Out:
# ['cheese',
#  'bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck']

# %%
shopping.pop(2) #remove defined position from list
# Out:
# 'eggs'

# %%
shopping
# Out:
# ['cheese', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
shopping[0] = "mozzarella"

# %%
shopping
# Out:
# ['mozzarella', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
words = s.split()

# %%
words[0]
# Out:
# 'The'

# %%
words[-1] #last word
# Out:
# 'dog'

# %%
words[3][1] #2nd letter of 4th word
# Out:
# 'o'

# %%
element = 'fluorine'
print(element[::-2])
# Out:
# eiol

# %%
print(element[::-1])
# Out:
# eniroulf

# %%
print(element[::-3])
# Out:
# erl
