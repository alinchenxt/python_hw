# %% [markdown]
# # Monday (03.11.)

# %% [markdown]
# ### math operations

# %%
10 % 3
# Out:
# 1

# %%
10 // 3
# Out:
# 3

# %%
2**32
# Out:
# 4294967296

# %%
8 * "hello "
# Out:
# 'hello hello hello hello hello hello hello hello '

# %%
(12**2 + 5**2)**0.5
# Out:
# 13.0

# %%
x = 3

# %%
y = (10 / 7)

# %%
y = 10 / 7

# %%
print(x, y)
# Out:
# 3 1.4285714285714286

# %%
x = x + y

# %%
print(x)
# Out:
# 4.428571428571429

# %%
x
# Out:
# 4.428571428571429

# %%
s = "the quick brown fox jumps over the lazy dog"

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
print(s)
# Out:
# the quick brown fox jumps over the lazy dog

# %%
s.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
s.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
s.capitalize()
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s = s.capitalize()

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s = s.lower()

# %% [markdown]
# how many times "the" comes up in s

# %%
s.count('the')
# Out:
# 2

# %%
s.lower().count('the')
# Out:
# 2

# %%
help(s.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
s.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
s.split('o')
# Out:
# ['The quick br', 'wn f', 'x jumps ', 'ver the lazy d', 'g']

# %%
s.split('\')  split at tab

# %%
s.split(",") # split at comma

# %%
x = "PiW7Bcfsp5pDxVt6zo2V6uFSGfTfYsmE8x8fQlfzSx3cEI0MwjyTDAHBSn4YBCZfNMp0ur7E94fKjywCuculuskE05gUFMaCFP2ZPUhgo6BfmJRYmFxJQUZTyhkOyzJ7g87Gv9LF9gfNRsG8bMLK9KjOeOzPzmbAcRww3Gscabra."

# %%
print(x[79:86], x[166:172])
# Out:
# Cuculus scabra

# %%
8 ^ 3
# Out:
# 11

# %%
first = 1.0
second = "1"
third = "1.1"

# %%
float(second) + float(third)
# Out:
# 2.1
